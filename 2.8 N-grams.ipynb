# %% [markdown]
# # 2.8 N-grams
#
# We can break our text down into n-grams to check our preprocessing, explore the contents of our data, or create new features for machine learning. An n-gram is simply a sequence of neighbouring n words (or tokens), where n can be any number.

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rolando/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tokens = ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']
print(len(tokens), tokens)

en_stopwords = stopwords.words('english')
tokens = [t for t in tokens if t not in (en_stopwords)]
print(len(tokens), tokens)
# Out:
# 107 ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']
# 57 ['rise', 'artificial', 'intelligence', 'led', 'significant', 'advancements', 'natural', 'language', 'processing', 'computer', 'vision', 'fields', 'machine', 'learning', 'algorithms', 'becoming', 'sophisticated', 'enabling', 'computers', 'perform', 'complex', 'tasks', 'thought', 'exclusive', 'domain', 'humans', 'advent', 'deep', 'learning', 'neural', 'networks', 'become', 'even', 'powerful', 'capable', 'processing', 'vast', 'amounts', 'data', 'learning', 'ways', 'possible', 'result', 'ai', 'increasingly', 'used', 'wide', 'range', 'industries', 'healthcare', 'finance', 'transportation', 'impact', 'set', 'grow', 'years', 'come']

# %%
# unigrams: n=1
unigrams = (pd.Series(nltk.ngrams(tokens, 1)).value_counts()) 
print(unigrams)
# Out:
# (learning,)          3
# (processing,)        2
# (rise,)              1
# (increasingly,)      1
# (become,)            1
# (even,)              1
# (powerful,)          1
# (capable,)           1
# (vast,)              1
# (amounts,)           1
# (data,)              1
# (ways,)              1
# (possible,)          1
# (result,)            1
# (ai,)                1
# (used,)              1
# (neural,)            1
# (wide,)              1
# (range,)             1
# (industries,)        1
# (healthcare,)        1
# (finance,)           1
# (transportation,)    1
# (impact,)            1
# (set,)               1
# (grow,)              1
# (years,)             1
# (networks,)          1
# (deep,)              1
# (artificial,)        1
# (algorithms,)        1
# (intelligence,)      1
# (led,)               1
# (significant,)       1
# (advancements,)      1
# (natural,)           1
# (language,)          1
# (computer,)          1
# (vision,)            1
# (fields,)            1
# (machine,)           1
# (becoming,)          1
# (advent,)            1
# (sophisticated,)     1
# (enabling,)          1
# (computers,)         1
# (perform,)           1
# (complex,)           1
# (tasks,)             1
# (thought,)           1
# (exclusive,)         1
# (domain,)            1
# (humans,)            1
# (come,)              1
# Name: count, dtype: int64

# %%
unigrams[0:10].sort_values().plot.barh(color='lightsalmon', width=.9, figsize=(12, 8))
plt.title('10 Most Frequently Occuring Unigrams')
plt.ylabel('Unigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %%
# bigrams: n=2
bigrams = (pd.Series(nltk.ngrams(tokens, 2)).value_counts()) 
print(len(bigrams))
# Out:
# 56

# %%
bigrams[0:10].sort_values().plot.barh(color='lightsalmon', width=.9, figsize=(12, 8))
plt.title('10 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %%
# trigrams: n=3
trigrams = (pd.Series(nltk.ngrams(tokens, 3)).value_counts()) 
print(len(trigrams))
# Out:
# 105

# %%
# Out:
# [1, 2, 3, 4, 3, 5, 6, 3, 7, 8, 9, 2]
# 3    3
# 2    2
# 1    1
# 4    1
# 5    1
# 6    1
# 7    1
# 8    1
# 9    1
# Name: count, dtype: int64
